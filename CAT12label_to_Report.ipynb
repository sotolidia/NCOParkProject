# %%
#!/usr/bin/env python
# coding: utf-8

#SE IMPORTAN LAS LIBRERIAS Y TOOLS
import xmltodict
import os
import pandas as pd
import numpy as np
PxID = input("Identificador del Paciente: ")
os.chdir("/Users/hecto/Desktop/Neuroimagen/ds003424-download")
neuro_dir = os.getcwd()

PxExists = os.path.isdir(neuro_dir + "/" + PxID) 

#--------------------------------------------------------------------------------------------------------------------------
#RECONOCIMIENTO DE PACIENTE
if PxExists:
    print("REPORTE DEL PACIENTE: " + PxID)
    print("REPORTE DEL ARCHIVO ROI:")
#--------------------------------------------------------------------------------------------------------------------------
#SE DECLARAN LAS RUTAS
    os.chdir(neuro_dir + "/" + PxID)
    ruta_xml = os.getcwd() + "/anat/catROI_" + PxID + "_T1w.xml"
    ruta_xmlS = os.getcwd() + "/anat/catROIs_" + PxID + "_T1w.xml"
    ruta_csv_Cobra = "anat/" + PxID + "_Cobra_ROI.csv"
    ruta_csv_Hammers = "anat/" + PxID + "_Hammers_ROI.csv"
    ruta_csv_Ibsr = "anat/" + PxID + "_Isbr_ROI.csv"
    ruta_csv_Lpba40 = "anat/" + PxID + "_Lpba40_ROI.csv"
    ruta_csv_Neuromorphometrics = "anat/" + PxID + "_Neuromorphometrics_ROI.csv"
    ruta_csv_Suit = "anat/" + PxID + "_Suit_ROI.csv"
    ruta_csv_Thalamus = "anat/" + PxID + "_Thalamus_ROI.csv"
    ruta_csv_Aparc_a2009s = "anat/" + PxID + "_A2009s_ROIs.csv"
    ruta_csv_Aparc_DK40 = "anat/" + PxID + "_DK40_ROIs.csv"
#--------------------------------------------------------------------------------------------------------------------------
#SE DECLARAN LAS LISTAS
    Cobra = []
    Hammers = []
    Ibsr = []
    Lpba40 = []
    Neuromorphometrics = []
    Suit = []
    Thalamus = []
    Aparc_a2009s = []
    Aparc_DK40 = []
    Schaefer = []
    FloatTV = []
    FloatTV2 = []
    FloatTV3 = []
    FloatTV4 = []
    FloatTV5 = []
    FloatTV6 = []
#--------------------------------------------------------------------------------------------------------------------------
#SE ABRE EL XML DEL QUE SE ADQUIRIRÁN LOS DATOS
    xml=open(ruta_xml)
#SE USA LA FUNCIÓN "PARSE" Y SE CONVIERTE EL XML A DICCIONARIO
    xmldict = xmltodict.parse(xml.read())
#--------------------------------------------------------------------------------------------------------------------------
#COBRA
#VGM
    for item in xmldict["S"]["cobra"]["names"]["item"]:
        Cobra.append(item)
    VgmTemp = '' 
    i=0
    for Vgm in xmldict["S"]["cobra"]["data"]["Vgm"]: 
        if(Vgm == '['):
            i=i+1
        elif(Vgm == ']'):
            i=i+1
        else:
            VgmTemp = VgmTemp + Vgm
            FloatVgm=VgmTemp.split(';')
            
#VGM
    VwmTemp = '' 
    for Vwm in xmldict["S"]["cobra"]["data"]["Vwm"]: 
        if(Vwm == '['):
            i=i+1
        elif(Vwm == ']'):
            i=i+1
        else:
            VwmTemp = VwmTemp + Vwm
    FloatVwm=VwmTemp.split(';')
#TV:
    for i in range(len(FloatVgm)):
        FloatTV.append(float(FloatVwm[i]) + float(FloatVgm[i]))
#SE DECLARA UN DATAFRAME CON LOS DATOS ORDENADOS
    df1 = pd.DataFrame(list(zip(Cobra,FloatVgm,FloatVwm,FloatTV)), columns = ['Cobra','Vmg','Vwm','TV'])
#--------------------------------------------------------------------------------------------------------------------------
#HAMMERS
    for item in xmldict["S"]["hammers"]["names"]["item"]:
        Hammers.append(item)
#VGM
    VgmTemp2 = '' 
    i=0
    
    for Vgm2 in xmldict["S"]["hammers"]["data"]["Vgm"]: 
        if(Vgm2 == '['):
            i=i+1
        elif(Vgm2 == ']'):
            i=i+1
        else:
            VgmTemp2 = VgmTemp2 + Vgm2
    FloatVgm2=VgmTemp2.split(';')
#VWM
    VwmTemp2 = '' 
    for Vwm2 in xmldict["S"]["hammers"]["data"]["Vwm"]: 
        if(Vwm2 == '['):
            i=i+1
        elif(Vwm2 == ']'):
            i=i+1
        else:
            VwmTemp2 = VwmTemp2 + Vwm2
    FloatVwm2=VwmTemp2.split(';')
#VCSF
    VcsfTemp2 = ''
    for Vcsf2 in xmldict["S"]["hammers"]["data"]["Vcsf"]: 
        if(Vcsf2 == '['):
            i=i+1
        elif(Vcsf2 == ']'):
            i=i+1
        else:
            VcsfTemp2 = VcsfTemp2 + Vcsf2
    FloatVcsf2=VcsfTemp2.split(';')
#TV:
    for i in range(len(FloatVgm2)):
        FloatTV2.append(float(FloatVwm2[i]) + float(FloatVgm2[i]) + float(FloatVcsf2[i]))
#SE DECLARA UN DATAFRAME CON LOS DATOS ORDENADOS                        
    df2 = pd.DataFrame(list(zip(Hammers,FloatVgm2,FloatVwm2, FloatVcsf2, FloatTV2)), columns = ['Hammers','Vmg','Vwm', 'Vcsf', 'TV'])
#--------------------------------------------------------------------------------------------------------------------------
#ISBR
    for item in xmldict["S"]["ibsr"]["names"]["item"]:
        Ibsr.append(item)
#VGM
    VgmTemp3 = '' 
    i=0
    
    for Vgm3 in xmldict["S"]["ibsr"]["data"]["Vgm"]: 
        if(Vgm3 == '['):
            i=i+1
        elif(Vgm3 == ']'):
            i=i+1
        else:
            VgmTemp3 = VgmTemp3 + Vgm3
    FloatVgm3=VgmTemp3.split(';')
#VWM
    VwmTemp3 = '' 
    for Vwm3 in xmldict["S"]["ibsr"]["data"]["Vwm"]: 
        if(Vwm3 == '['):
            i=i+1
        elif(Vwm3 == ']'):
            i=i+1
        else:
            VwmTemp3 = VwmTemp3 + Vwm3
    FloatVwm3=VwmTemp3.split(';')
#VCSF
    VcsfTemp3 = ''
    for Vcsf3 in xmldict["S"]["ibsr"]["data"]["Vcsf"]: 
        if(Vcsf3 == '['):
            i=i+1
        elif(Vcsf3 == ']'):
            i=i+1
        else:
            VcsfTemp3 = VcsfTemp3 + Vcsf3
    FloatVcsf3=VcsfTemp3.split(';')
#TV:
    for i in range(len(FloatVgm3)):
        FloatTV3.append(float(FloatVwm3[i]) + float(FloatVgm3[i]) + float(FloatVcsf3[i]))
#SE DECLARA UN DATAFRAME CON LOS DATOS ORDENADOS                        
    df3 = pd.DataFrame(list(zip(Ibsr,FloatVgm3,FloatVwm3, FloatVcsf3, FloatTV3)), columns = ['Ibsr','Vmg','Vwm', 'Vcsf', 'TV'])
#--------------------------------------------------------------------------------------------------------------------------
#LPBA40
#VGM
    for item in xmldict["S"]["lpba40"]["names"]["item"]:
        Lpba40.append(item)
    VgmTemp4 = '' 
    i=0
    for Vgm4 in xmldict["S"]["lpba40"]["data"]["Vgm"]: 
        if(Vgm4 == '['):
            i=i+1
        elif(Vgm4 == ']'):
            i=i+1
        else:
            VgmTemp4 = VgmTemp4 + Vgm4
            FloatVgm4=VgmTemp4.split(';')
            
#VGM
    VwmTemp4 = '' 
    for Vwm4 in xmldict["S"]["lpba40"]["data"]["Vwm"]: 
        if(Vwm4 == '['):
            i=i+1
        elif(Vwm4 == ']'):
            i=i+1
        else:
            VwmTemp4 = VwmTemp4 + Vwm4
    FloatVwm4=VwmTemp4.split(';')
#TV:
    for i in range(len(FloatVgm)):
        FloatTV4.append(float(FloatVwm4[i]) + float(FloatVgm4[i]))
#SE DECLARA UN DATAFRAME CON LOS DATOS ORDENADOS
    df4 = pd.DataFrame(list(zip(Lpba40,FloatVgm4,FloatVwm4,FloatTV4)), columns = ['Lpba40','Vmg','Vwm','TV'])
#--------------------------------------------------------------------------------------------------------------------------
#NEUROMORPHOTOMETRICS
    for item in xmldict["S"]["neuromorphometrics"]["names"]["item"]:
        Neuromorphometrics.append(item)
#VGM
    VgmTemp5 = '' 
    i=0
    
    for Vgm5 in xmldict["S"]["neuromorphometrics"]["data"]["Vgm"]: 
        if(Vgm5 == '['):
            i=i+1
        elif(Vgm5 == ']'):
            i=i+1
        else:
            VgmTemp5 = VgmTemp5 + Vgm5
    FloatVgm5=VgmTemp5.split(';')
#VWM
    VwmTemp5 = '' 
    for Vwm5 in xmldict["S"]["neuromorphometrics"]["data"]["Vwm"]: 
        if(Vwm5 == '['):
            i=i+1
        elif(Vwm5 == ']'):
            i=i+1
        else:
            VwmTemp5 = VwmTemp5 + Vwm5
    FloatVwm5=VwmTemp5.split(';')
#VCSF
    VcsfTemp5 = ''
    for Vcsf5 in xmldict["S"]["neuromorphometrics"]["data"]["Vcsf"]: 
        if(Vcsf5 == '['):
            i=i+1
        elif(Vcsf5 == ']'):
            i=i+1
        else:
            VcsfTemp5 = VcsfTemp5 + Vcsf5
    FloatVcsf5=VcsfTemp5.split(';')
#TV:
    for i in range(len(FloatVgm5)):
        FloatTV5.append(float(FloatVwm5[i]) + float(FloatVgm5[i]) + float(FloatVcsf5[i]))
#SE DECLARA UN DATAFRAME CON LOS DATOS ORDENADOS                        
    df5 = pd.DataFrame(list(zip(Neuromorphometrics,FloatVgm5,FloatVwm5, FloatVcsf5, FloatTV5)), columns = ['Neuromorphometrics','Vmg','Vwm', 'Vcsf', 'TV'])
#--------------------------------------------------------------------------------------------------------------------------
#SUIT
#VGM
    for item in xmldict["S"]["suit"]["names"]["item"]:
        Suit.append(item)
    VgmTemp6 = '' 
    i=0
    for Vgm6 in xmldict["S"]["suit"]["data"]["Vgm"]: 
        if(Vgm6 == '['):
            i=i+1
        elif(Vgm6 == ']'):
            i=i+1
        else:
            VgmTemp6 = VgmTemp6 + Vgm6
            FloatVgm6=VgmTemp6.split(';')
            
#VGM
    VwmTemp6 = '' 
    for Vwm6 in xmldict["S"]["suit"]["data"]["Vwm"]: 
        if(Vwm6 == '['):
            i=i+1
        elif(Vwm6 == ']'):
            i=i+1
        else:
            VwmTemp6 = VwmTemp6 + Vwm6
    FloatVwm6=VwmTemp6.split(';')
#TV:
    for i in range(len(FloatVgm6)):
        FloatTV6.append(float(FloatVwm6[i]) + float(FloatVgm6[i]))
#SE DECLARA UN DATAFRAME CON LOS DATOS ORDENADOS
    df6 = pd.DataFrame(list(zip(Suit,FloatVgm6,FloatVwm6,FloatTV6)), columns = ['Suit','Vmg','Vwm','TV'])
#--------------------------------------------------------------------------------------------------------------------------
#THALAMUS
#VGM
    for item in xmldict["S"]["thalamus"]["names"]["item"]:
        Thalamus.append(item)
    VgmTemp7 = '' 
    i=0
    for Vgm7 in xmldict["S"]["thalamus"]["data"]["Vgm"]: 
        if(Vgm7 == '['):
            i=i+1
        elif(Vgm7 == ']'):
            i=i+1
        else:
            VgmTemp7 = VgmTemp7 + Vgm7
            FloatVgm7=VgmTemp7.split(';')
#SE DECLARA UN DATAFRAME CON LOS DATOS ORDENADOS
    df7 = pd.DataFrame(list(zip(Thalamus,FloatVgm7)), columns = ['Thalamus','Vmg'])
#--------------------------------------------------------------------------------------------------------------------------
#SE ABRE EL XML DEL QUE SE ADQUIRIRÁN LOS DATOS
    xmlS=open(ruta_xmlS)
#SE USA LA FUNCIÓN "PARSE" Y SE CONVIERTE EL XML A DICCIONARIO
    xmldictS = xmltodict.parse(xmlS.read())
#--------------------------------------------------------------------------------------------------------------------------
#APARC_A2009S
#THICKNESS
    for item in xmldictS["S"]["aparc_a2009s"]["names"]["item"]:
        Aparc_a2009s.append(item)
    thTemp = '' 
    i=0
    for th in xmldictS["S"]["aparc_a2009s"]["data"]["thickness"]: 
        if(th == '['):
            i=i+1
        elif(th == ']'):
            i=i+1
        else:
            thTemp = thTemp + th
            Floatth=thTemp.split(';')
            
#SE DECLARA UN DATAFRAME CON LOS DATOS ORDENADOS
    df8 = pd.DataFrame(list(zip(Aparc_a2009s,Floatth)), columns = ['aparc_a2009s','Thickness'])
#--------------------------------------------------------------------------------------------------------------------------
#APARC__DK40
#THICKNESS
    for item in xmldictS["S"]["aparc_DK40"]["names"]["item"]:
        Aparc_DK40.append(item)
    thTemp2 = '' 
    i=0
    for th2 in xmldictS["S"]["aparc_DK40"]["data"]["thickness"]: 
        if(th2 == '['):
            i=i+1
        elif(th2 == ']'):
            i=i+1
        else:
            thTemp2 = thTemp2 + th2
            Floatth2=thTemp2.split(';')
            
#SE DECLARA UN DATAFRAME CON LOS DATOS ORDENADOS
    df9 = pd.DataFrame(list(zip(Aparc_DK40,Floatth2)), columns = ['aparc_DK40','Thickness'])
#--------------------------------------------------------------------------------------------------------------------------
#VISUALIZACIÓN DEL REPORTE COMO DATAFRAME
    print(df1)
    print(df2)
    print(df3)
    print(df4)
    print(df5)
    print(df6)
    print(df7)
    print(df8)
    print(df9)
#--------------------------------------------------------------------------------------------------------------------------
#CONVERSION DE DATAFRAMES A CSVs
    df1.to_csv(ruta_csv_Cobra)
    df2.to_csv(ruta_csv_Hammers)
    df3.to_csv(ruta_csv_Ibsr)
    df4.to_csv(ruta_csv_Lpba40)
    df5.to_csv(ruta_csv_Neuromorphometrics)
    df6.to_csv(ruta_csv_Suit)
    df7.to_csv(ruta_csv_Thalamus)
    df8.to_csv(ruta_csv_Aparc_a2009s)
    df9.to_csv(ruta_csv_Aparc_DK40)
    
else:
    print("El paciente no se encuentra en la base de datos")
# Out:
# Identificador del Paciente: sub-28
# REPORTE DEL PACIENTE: sub-28
# REPORTE DEL ARCHIVO ROI:
#                   Cobra                 Vmg                  Vwm         TV
# 0             lStriatum     8.5597543523761     1.58475243237888  10.144507
# 1               lGloPal    0.24902867951937     1.49524166332071   1.744270
# 2                  lTha    4.21741341334325     2.84418222888405   7.061596
# 3        lAntCerebLI_II   0.074734407746746   0.0172035371122092   0.091938
# 4         lAntCerebLIII   0.775849591434508    0.225684225817702   1.001534
# 5          lAntCerebLIV    1.93170287360545    0.681061849114428   2.612765
# 6           lAntCerebLV    4.12912184324199    0.901031511510553   5.030153
# 7      lSupPostCerebLVI    7.74371955972697     1.38941001014814   9.133130
# 8       lSupPostCerebCI    10.1817038441254     3.32843561186991  13.510139
# 9      lSupPostCerebCII    7.72283223534487     2.62906321509604  10.351895
# 10   lSupPostCerebLVIIB    4.64117763961269     1.41319202700174   6.054370
# 11  lInfPostCerebLVIIIA     6.3943863259297     1.48905214521022   7.883438
# 12  lInfPostCerebLVIIIB    3.99769803637895    0.896711926245075   4.894410
# 13     lInfPostCerebLIX    3.88434543465621    0.953345222626467   4.837691
# 14      lInfPostCerebLX   0.647589745142341    0.082606897244375   0.730197
# 15          lAntCerebWM   0.877728198133809     7.93519489604222   8.812923
# 16                 lAmy    1.44537009705914   0.0844805860680253   1.529851
# 17                lHCA1    0.96223495004466    0.156851378797285   1.119086
# 18                 lSub   0.319342521436283   0.0595391977640247   0.378882
# 19                 lFor  0.0645057838681851    0.290728555008002   0.355234
# 20                 lCA4   0.890522377829939   0.0147501631317937   0.905273
# 21               lCA2_3   0.162939932138784  0.00356786398469922   0.166508
# 22             lStratum   0.675283695088069    0.034773584346226   0.710057
# 23              lFimbra  0.0654070994983158   0.0428405471382121   0.108248
# 24             lMamBody   0.018351685994844  0.00963398085218614   0.027986
# 25              lAlveus   0.396833235072336    0.048368118420683   0.445201
# 26            rStriatum    8.51179761945531     1.64503586321274  10.156833
# 27              rGloPal   0.239828527000441     1.40430601064523   1.644135
# 28                 rTha     3.8087022575537     2.87437817834046   6.683080
# 29       rAntCerebLI_II   0.111381681023204   0.0211379111831889   0.132520
# 30        rAntCerebLIII   0.911065651365561    0.374397583101427   1.285463
# 31         rAntCerebLIV    2.07963832659175    0.580989623637507   2.660628
# 32          rAntCerebLV    4.36139577026751     1.05847005444559   5.419866
# 33     rSupPostCerebLVI    9.49908990886428     1.51805880811651  11.017149
# 34      rSupPostCerebCI    10.1519117943489     3.26596807401813  13.417880
# 35     rSupPostCerebCII    7.83709364195317     3.86507750008569  11.702171
# 36   rSupPostCerebLVIIB    4.72752069499904     1.64802030344191   6.375541
# 37  rInfPostCerebLVIIIA    4.62619185427826    0.981308449723883   5.607500
# 38  rInfPostCerebLVIIIB    3.80876954524467    0.908066259945883   4.716836
# 39     rInfPostCerebLIX    3.77541338902887     1.06875851567168   4.844172
# 40      rInfPostCerebLX   0.643202843320978   0.0854567004608953   0.728660
# 41          rAntCerebWM     1.1317384182945     8.32387141037572   9.455610
# 42                 rAmy    1.49474798622862   0.0277051745456447   1.522453
# 43                rHCA1   0.965873871166423    0.126423558235444   1.092297
# 44                 rSub    0.29067993291676   0.0627218520037331   0.353402
# 45                 rFor   0.127287473830506    0.330599620745886   0.457887
# 46                 rCA4   0.920355553915897  0.00320509371931621   0.923561
# 47               rCA2_3   0.198783126819535  0.00235613660493073   0.201139
# 48             rStratum   0.604958628706243   0.0223870375606339   0.627346
# 49              rFimbra  0.0956853238562871   0.0244776413040881   0.120163
# 50             rMamBody  0.0207564413585715   0.0107185516213804   0.031475
# 51              rAlveus   0.345746210228981   0.0303866823259113   0.376133
#                                     Hammers               Vmg  \
# 0                          TL hippocampus R  2.77500527224817
# 1                          TL hippocampus L  2.60048287267978
# 2                             TL amygdala R   1.6243093179753
# 3                             TL amygdala L   1.6456978031556
# 4   TL anterior temporal lobe medial part R  6.30039518035108
# ..                                      ...               ...
# 90           insula posterior short gyrus R  1.62182603301631
# 91        insula anterior inferior cortex L  2.09669974456972
# 92        insula anterior inferior cortex R  1.95781484589475
# 93             insula anterior long gyrus L  1.98925992014054
# 94             insula anterior long gyrus R  1.97720622312225
#
#                    Vwm                Vcsf        TV
# 0    0.149816628677968  0.0363368621236759  2.961159
# 1    0.195088110089614  0.0425637946221968  2.838135
# 2   0.0672620898853893  0.0126445998631652  1.704216
# 3    0.114115548967675  0.0264186492273666  1.786232
# 4     2.14299222939474   0.537363698214222  8.980751
# ..                 ...                 ...       ...
# 90   0.549660484196579   0.179320693874274  2.350807
# 91   0.608309584855249    0.19988266005555  2.904892
# 92   0.710034846385099   0.215107790793923  2.882957
# 93    1.24858034283193   0.408082855145153  3.645923
# 94    1.25217064450567   0.380299143145635  3.609676
#
# [95 rows x 5 columns]
#           Ibsr                 Vmg                   Vwm  \
# 0       lCbrWM    33.9889867430716      190.530732628964
# 1       lCbrGM     309.62197747928      57.9816826312225
# 2      lLatVen   0.237401331943943     0.313287632977222
# 3   lInfLatVen  0.0344893514352407  0.000680661685237283
# 4       lCbeWM     1.3632307111493       11.065722476161
# 5       lCbeGM    55.3513736736448       12.518310781509
# 6      lThaPro    4.81102893408192      3.68863279275899
# 7         lCau    3.20507499188238     0.109193842618538
# 8         lPut    4.37021444891172      1.24122397424742
# 9         lPal   0.240262355163168      1.39910381130903
# 10     b3thVen   0.121071761824965   0.00538919505288504
# 11     b4thVen   0.154169871251497    0.0230415200235257
# 12        bBst    1.21019028772196      20.8674749422997
# 13        lHip    4.25377641499836     0.385736959621852
# 14        lAmy    1.71976276908481    0.0922184383256308
# 15        bCSF  0.0417746759922011    0.0194287773922497
# 16        lAcc   0.603133557433466    0.0134673776983618
# 17      lVenDC    1.05486104745012       3.7963007216959
# 18      rCbrWM    36.2355218211472       193.88267721137
# 19      rCbrGM    312.261471177828      55.7013538373567
# 20     rLatVen   0.302228748182642     0.385419071854187
# 21  rInfLatVen  0.0267402801910066    0.0121621526147919
# 22      rCbeWM    1.73052248192107       11.300019689779
# 23      rCbeGM    55.2647912417648      13.9037340401682
# 24     rThaPro    4.47059338047096      3.70225724803674
# 25        rCau    3.14112645186526    0.0445309822652007
# 26        rPut    4.32969263913208      1.16281698409182
# 27        rPal   0.183169051709342       1.4170964649125
# 28        rHip    4.22659108475187     0.317988683256942
# 29        rAmy    1.90016803037452    0.0571718415756095
# 30        rAcc     0.5509806620978    0.0193165802926387
# 31      rVenDC    1.07576334438875       3.5419913104775
#
#                     Vcsf          TV
# 0       2.56260896675098  227.082328
# 1       71.5729479932534  439.176608
# 2       7.62490667112914    8.175596
# 3    0.00774533164360491    0.042915
# 4     0.0967212770319748   12.525674
# 5       8.65146051028631   76.521145
# 6      0.617973489745793    9.117635
# 7       0.23926006150532    3.553529
# 8    0.00188864916594866    5.613327
# 9                      0    1.639366
# 10     0.844405682499882    0.970867
# 11      1.32778392530497    1.504995
# 12      3.64091168695069   25.718577
# 13      0.18609365241673    4.825607
# 14    0.0667646834102698    1.878746
# 15      1.10525243653825    1.166456
# 16  0.000426348520932152    0.617027
# 17     0.504306727108883    5.355468
# 18      1.89355219134901  232.011751
# 19      65.7415735473137  433.704399
# 20      5.00287076981465    5.690519
# 21   0.00687393503540079    0.045776
# 22    0.0520070404803619   13.082549
# 23      7.27530096710893   76.443826
# 24     0.563150305030291    8.736001
# 25     0.201883507301659    3.387541
# 26   0.00351550539789969    5.496025
# 27                     0    1.600266
# 28     0.140882008707877    4.685462
# 29    0.0911600466224627    2.048500
# 30                     0    0.570297
# 31     0.521166192015698    5.138921
#       Lpba40               Vmg                 Vwm         TV
# 0   lSupFroG  41.0091776918153    22.7201388392899  63.729317
# 1   rSupFroG  39.6302207130539    19.6963928591387  59.326614
# 2   lMidFroG  32.6738210171351    22.0084060532884  54.682227
# 3   rMidFroG   31.382845171676    22.4854900362743  53.868335
# 4   lInfFroG  15.6444214041045    8.27425793399073  23.918679
# 5   rInfFroG  16.7544646561382    8.80332279010076  25.557787
# 6      lPrcG  16.3132276227023    11.0628502772983  27.376078
# 7      rPrcG  16.5703269996489    11.8102915876079  28.380619
# 8   lMidOrbG  7.04405920920337    2.98323914310572  10.027298
# 9   rMidOrbG  7.14394443832589    2.82483570831005   9.968780
# 10  lLatOrbG   4.6979081722931    1.40482959899657   6.102738
# 11  rLatOrbG  4.35556152720551    1.42743728920891   5.782999
# 12     lRecG   2.0755132198218   0.669995483818298   2.745509
# 13     rRecG   2.4664448953553   0.812624024334241   3.279069
# 14     lPoCG  13.0597433616773    8.96995400552214  22.029697
# 15     rPoCG  13.3152046615752    9.24341544212837  22.558620
# 16  lSupParG  14.8632162933748    10.3273766283536  25.190593
# 17  rSupParG  15.6399859015193    9.80143833430702  25.441424
# 18  lSupMarG  11.7378310444427    4.04111828142106  15.778949
# 19  rSupMarG  12.0752858967785    4.05593202313526  16.131218
# 20     lAngG  14.2164044352207    4.03634243509998  18.252747
# 21     rAngG   15.709592877247    4.49456986153507  20.204163
# 22      lPCu  9.25066711041822    2.69538283752979  11.946050
# 23      rPCu   9.3688778467822    2.62862937718467  11.997507
# 24  lSupOccG  4.73391593437889    2.32795642456551   7.061872
# 25  rSupOccG  5.21931747000082    3.04064659594872   8.259964
# 26  lMidOccG  16.7275673177287    9.63154219633822  26.359110
# 27  rMidOccG  17.6759908155244    9.54973190441422  27.225723
# 28  lInfOccG  7.78622727207701    4.40302459776376  12.189252
# 29  rInfOccG  8.26036796939356    4.43427520286832  12.694643
# 30      lCun   4.8709047098896    2.09414914501593   6.965054
# 31      rCun  4.62820395094354    2.26552255373491   6.893727
# 32  lSupTemG  21.5047950040868    7.64239075485307  29.147186
# 33  rSupTemG  22.9850471391844    8.65777714901128  31.642824
# 34  lMidTemG  19.9637993839641    8.47172088225534  28.435520
# 35  rMidTemG  19.8423311914695    8.67341739038352  28.515749
# 36  lInfTemG  16.5252424830431    7.85516856961976  24.380411
# 37  rInfTemG  16.2574544628775    6.85758409514392  23.115039
# 38  lParHipG  4.84195413354627    1.84488859403587   6.686843
# 39  rParHipG  4.33168227606018    1.85144463751641   6.183127
# 40     lLinG  9.58238872724859    5.35793683545904  14.940326
# 41     rLinG  9.65824136528326     5.6741752419498  15.332417
# 42     lFusG  11.0247182493737    3.97725202165589  15.001970
# 43     rFusG  10.7952268095204     4.1716332863615  14.966860
# 44      lIns  7.90586288982808    1.14082263788617   9.046686
# 45      rIns  7.58301234044012   0.985571935927965   8.568584
# 46     lCinG  11.4664527151902    3.20387076601492  14.670323
# 47     rCinG  13.1292605587454    3.21734562561105  16.346606
# 48      lCau  2.47176301985519  0.0787361021252764   2.550499
# 49      rCau  2.32248119718292  0.0271928085169293   2.349674
# 50      lPut  3.49336888355367      1.691758422254   5.185127
# 51      rPut  3.50425946844268    1.58036551957252   5.084625
#                                     Neuromorphometrics                 Vmg  \
# 0                                        3rd Ventricle  0.0967848558559581
# 1                                        4th Ventricle   0.220242672568816
# 2                                 Right Accumbens Area    0.44904970664561
# 3                                  Left Accumbens Area   0.522243275497658
# 4                                       Right Amygdala    1.04824141082815
# ..                                                 ...                 ...
# 131                             Left TMP temporal pole    10.4207581877027
# 132  Right TrIFG triangular part of the inferior fr...    3.96574808664241
# 133  Left TrIFG triangular part of the inferior fro...     4.5088749628448
# 134                Right TTG transverse temporal gyrus    1.80661072283783
# 135                 Left TTG transverse temporal gyrus    1.80474077207293
#
#                      Vwm                  Vcsf         TV
# 0    0.00544903345200964     0.799971938732824   0.902206
# 1      0.069880019395896      1.39710295938755   1.687226
# 2    0.00253939170136164  0.000452527814331916   0.452042
# 3    0.00379973781150511   0.00133888400455362   0.527382
# 4    0.00833623570883901    0.0611286545648682   1.117706
# ..                   ...                   ...        ...
# 131     1.36811875815113      3.95723982356344  15.746117
# 132    0.710046067098347      1.26273586931802   5.938530
# 133    0.852106143170772      1.24035257245225   6.601334
# 134    0.282093128816996     0.350795078617239   2.439499
# 135     0.24325801460634     0.416295674924072   2.464294
#
# [136 rows x 5 columns]
#              Suit                  Vmg                  Vwm         TV
# 0       Left I IV     2.36566209058253    0.805035772444285   3.170698
# 1      Right I IV     3.27395647225615    0.970885348955619   4.244842
# 2          Left V      3.6517236995337     1.07739394277928   4.729118
# 3         Right V     4.20786542304796     1.01355012342452   5.221416
# 4         Left VI     8.38931219815464      1.8868801982137  10.276192
# 5       Vermis VI     1.42080644717879    0.356068337211468   1.776875
# 6        Right VI     8.71097344987959      1.4005399514545  10.111513
# 7      Left CrusI     10.3723003345806     3.00759713086052  13.379897
# 8    Vermis CrusI  0.00966763977316987  0.00124912637033958   0.010917
# 9     Right CrusI     9.68920396928397     2.67604383562059  12.365248
# 10    Left CrusII     8.95956083989091     3.12299920044268  12.082560
# 11  Vermis CrusII    0.278285908578368   0.0761892299294686   0.354475
# 12   Right CrusII      8.2842322597827     3.30122036164759  11.585453
# 13      Left VIIb     5.34455546074497     1.50391076399359   6.848466
# 14    Vermis VIIb    0.144131979510576     0.05079905265859   0.194931
# 15     Right VIIb      5.0775303945727     2.04001036933477   7.117541
# 16     Left VIIIa     5.46000988771311     1.06830598862473   6.528316
# 17   Vermis VIIIa     1.06162651968589    0.485012586068478   1.546639
# 18    Right VIIIa     4.52056962340919      1.0258543898658   5.546424
# 19     Left VIIIb     4.18954365272839    0.567540947251644   4.757085
# 20   Vermis VIIIb    0.685373946481604    0.127796101736521   0.813170
# 21    Right VIIIb     3.99669200901087    0.816958572414705   4.813651
# 22        Left IX     2.93295993392917    0.654471167848669   3.587431
# 23      Vermis IX    0.801512780881808    0.201109349163175   1.002622
# 24       Right IX     3.40177126954444    0.816939874191291   4.218711
# 25         Left X    0.522202141354455    0.113677980543514   0.635880
# 26       Vermis X    0.241193586916211   0.0151353727346759   0.256329
# 27        Right X    0.529726819294751    0.109294818386729   0.639022
#                                              Thalamus                Vmg
# 0                                           lPulvinar  0.541791738590369
# 1                                           lAnterior  0.770860571754461
# 2                                       lMedio_Dorsal  0.998654094956919
# 3                              lVentral_Latero_Dorsal   0.76053844626145
# 4   lCentral_Lateral-Lateral_Posterior-Medial_Pulv...   0.84087147864409
# 5                                   lVentral_Anterior  0.961412184229182
# 6                             lVentral_Latero_Ventral  0.131588359565171
# 7                                           rPulvinar  0.805050730317003
# 8                                           rAnterior  0.592411276603144
# 9                                       rMedio_Dorsal  0.890563524890808
# 10                             rVentral_Latero_Dorsal  0.675111667448824
# 11  rCentral_Lateral-Lateral_Posterior-Medial_Pulv...   0.77943989332141
# 12                                  rVentral_Anterior  0.591289306355769
# 13                            rVentral_Latero_Ventral  0.102925770818274
#                aparc_a2009s         Thickness
# 0                  lUnknown  1.67559360380932
# 1                  rUnknown  1.55557132092152
# 2     lG_and_S_frontomargin  2.46790667971828
# 3     rG_and_S_frontomargin  2.53719998825164
# 4    lG_and_S_occipital_inf  2.42437180711034
# ..                      ...               ...
# 147         rS_temporal_inf   2.7646556425501
# 148         lS_temporal_sup  2.66803248356188
# 149         rS_temporal_sup  2.87326445606111
# 150  lS_temporal_transverse  2.28321324468504
# 151  rS_temporal_transverse  2.51859984790442
#
# [152 rows x 2 columns]
#                   aparc_DK40         Thickness
# 0                   lunknown  0.74603459239006
# 1                   runknown               NaN
# 2                  lbankssts  2.48680231305668
# 3                  rbankssts  2.87018949667396
# 4   lcaudalanteriorcingulate  2.52721890552413
# ..                       ...               ...
# 67             rtemporalpole  3.23585409666508
# 68       ltransversetemporal  2.59086010789961
# 69       rtransversetemporal  2.73798502025775
# 70                   linsula  3.26564656565353
# 71                   rinsula  3.40954394675425
#
# [72 rows x 2 columns]

# %%
from fpdf import FPDF
